# %%
import os
import pandas as pd
import seaborn as sns
import csv
import io
import ssl
from datetime import date
from urllib.request import Request, urlopen
from datetime import date, datetime, timedelta
import random
# 1. ดาวน์โหลดฟอนต์ภาษาไทย (TH Sarabun New)
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

import matplotlib as mpl
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# 2. นำฟอนต์เข้าสู่ระบบของ Matplotlib
fm.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New', size=14)

# ฟังก์ชันที่ 1: คำนวณวันกำหนดส่ง (มี parameter, มี return)
def calculate_due_date(start_date_str: str, duration_days: int) -> str:
    """คำนวณวันกำหนดส่งคืนจากวันที่เริ่มเช่าและจำนวนวัน"""
    start_date_obj = datetime.strptime(start_date_str, "%Y-%m-%d %H:%M:%S")
    due_date_obj = start_date_obj + timedelta(days=duration_days)
    return due_date_obj.strftime("%Y-%m-%d")


# ฟังก์ชันที่ 2: จัดรูปแบบราคา (มี parameter, มี return)
def format_currency(amount: float) -> str:
    """จัดรูปแบบตัวเลขเป็นข้อความสกุลเงิน บาท"""
    return f"{amount:,.2f} บาท"


#ของกร
# ==================================================
# 1. ระบบจัดการสมาชิก (Customer & CustomerManager)
# ==================================================
class Customer:
    def __init__(self, name: str, customer_id: str, phone: str, email: str = "", points: int = 0, register_date: str = None, status: str = "ปกติ"):
        self.name = name
        self.customer_id = customer_id
        self.phone = phone
        self.email = email
        self.points = points
        self.register_date = register_date or str(date.today())
        self.status = status

    def add_points(self, amount: int):
        self.points += amount
        print(f"[ระบบแต้ม] เพิ่ม {self.name} +{amount} แต้ม (สะสมรวม:"f" {self.points} แต้ม)")

    def update_info(self, name: str = None, phone: str = None, email: str = None):
        if name:
            self.name = name
        if phone:
            self.phone = phone
        if email:
            self.email = email
        print(f"[อัปเดตข้อมูล] แก้ไขข้อมูล {self.name} เรียบร้อย")

class CustomerManager:
    def __init__(self):
        self.customers_db = {}
        self.last_id_number = 0

    def register_customer(self, name: str, phone: str, email: str = ""):
        if phone in self.customers_db:
            print(f" ไม่สามารถสมัครได้: เบอร์โทร {phone} เป็นสมาชิกอยู่แล้ว")
            return self.customers_db[phone]
        self.last_id_number += 1
        new_id = f"CUST{self.last_id_number:03d}"
        new_customer = Customer(
            name=name,
            customer_id=new_id,
            phone=phone,
            email=email,
            points=0,
            )
        self.customers_db[phone] = new_customer
        print(
            f"สมัครสำเร็จ [รหัส: {new_id} | ชื่อ: {name} | เบอร์: {phone} |"
            f" วันที่: {new_customer.register_date}]"
        )
        return new_customer

    def find_customer_by_phone(self, phone: str):
        customer = self.customers_db.get(phone)
        if customer:
            print(
                f"พบข้อมูล: {customer.name} (รหัส:{customer.customer_id}"
                f"แต้ม: {customer.points})"
            )
            return customer
        else:
            print(f" ไม่พบข้อมูลสมาชิกจากเบอร์โทร: {phone}")
            return None
#ของกวาง
import csv
import io
import ssl
from urllib.request import Request, urlopen

# ==================================================
# 1. Class Book (โครงสร้างข้อมูลหนังสือ)
# ==================================================
class Book:
    """คลาสสำหรับเก็บข้อมูลหนังสือการ์ตูนแต่ละเล่ม"""

    def __init__(self,
        book_isbn: str,
        title: str,
        author: str,
        price: str | float,
        category_id: str,
        sub_category_id: str,
        shelf_location: str,
        stock_qty: str | int,):

        self.book_isbn = str(book_isbn).strip()
        self.title = str(title).strip()
        self.author = str(author).strip()

        try:
            self.price = float(price) if price else 0.0
        except ValueError:
            self.price = 0.0

        try:
            self.stock_qty = int(stock_qty) if stock_qty else 0
        except ValueError:
            self.stock_qty = 0

        self.category_id = str(category_id).strip()
        self.sub_category_id = str(sub_category_id).strip()
        self.shelf_location = str(shelf_location).strip()

    @property
    def status(self) -> str:
        """สถานะการเช่า: ถ้าสต็อก > 0 เป็น 'พร้อมเช่า' ถ้าสต็อก <= 0 เป็น 'สินค้าหมด'"""
        return "พร้อมเช่า" if self.stock_qty > 0 else "สินค้าหมด"

    def is_available(self) -> bool:
        return self.stock_qty > 0

    def decrease_stock(self, qty: int = 1) -> bool:
        if self.stock_qty >= qty:
            self.stock_qty -= qty
            return True
        return False

    def increase_stock(self, qty: int = 1):
        self.stock_qty += qty

#ของตุ
# ==================================================
# 2. Class BookCatalogManager (ค้นหาและแสดงผล UI ตาราง)
# ==================================================
class BookCatalogManager:
    """ระบบคลังหนังสือหน้าร้าน พร้อมหน้าจอแสดงผลค้นหาแบบตาราง"""

    def __init__(self, csv_url: str):
        self.csv_url = csv_url
        self.books_by_isbn = {}
        self.catalog = []
        self.load_books_from_url()

    def load_books_from_url(self):
        """ดึงข้อมูล CSV จาก URL บน GitHub แล้วแปลงเป็น Object Book"""
        try:
            context = ssl._create_unverified_context()
            req = Request(self.csv_url, headers={"User-Agent": "Mozilla/5.0"})

            response = urlopen(req, context=context)
            csv_data = response.read().decode("utf-8-sig")

            reader = csv.DictReader(io.StringIO(csv_data))

            self.books_by_isbn.clear()
            self.catalog.clear()

            for row in reader:
                book = Book(book_isbn=row.get("book_isbn", ""),
                    title=row.get("title", ""),
                    author=row.get("author", ""),
                    price=row.get("price", 0),
                    category_id=row.get("category_id", ""),
                    sub_category_id=row.get("sub_category_id", ""),
                    shelf_location=row.get("shelf_location", ""),
                    stock_qty=row.get("stock_qty", 0),)

                self.catalog.append(book)
                if book.book_isbn:
                    self.books_by_isbn[book.book_isbn] = book

            print(" ระบบพร้อมใช้งาน: โหลดข้อมูลหนังสือเรียบร้อย"f" {len(self.catalog)} รายการ\n")

        except Exception as e:
            print(f" เกิดข้อผิดพลาดในการโหลดไฟล์ CSV: {e}\n")

    def search_by_title(self, keyword: str):
        """ค้นหาด้วยชื่อหนังสือ"""
        print(f" ผลการค้นหาชื่อหนังสือ: '{keyword}'")
        results = [
            b
            for b in self.catalog
            if keyword.lower().strip() in b.title.lower()]
        self._show_results(results)

    def search_by_isbn(self, isbn_code: str):
        """ค้นหาด้วยรหัส ISBN / บาร์โค้ด"""
        print(f" ผลการค้นหารหัส/ISBN: '{isbn_code}'")
        results = [
            b
            for b in self.catalog
            if isbn_code.lower().strip() in b.book_isbn.lower()]
        self._show_results(results)

    def _show_results(self, results: list[Book]):
        """แสดงผลลัพธ์การค้นหาในรูปแบบกรอบตาราง Terminal UI"""
        if not results:
            print(" ไม่พบข้อมูลหนังสือที่คุณต้องการค้นหา\n")
            return

        print(f"พบรายการหนังสือทั้งหมด {len(results)} รายการ")
        print("┌" + "─" * 76 + "┐")

        for i, b in enumerate(results, 1):
            print(f"  [{i:02d}] {b.title}")
            print(f"       ISBN: {b.book_isbn:<14} ผู้แต่ง: {b.author:<22}"f" ชั้นวาง: {b.shelf_location}")
            print(f"       ราคา: {b.price:>6.2f} บาท             สถานะ:"f" {b.status} (คงเหลือ {b.stock_qty} เล่ม)")

            if i < len(results):
                print("  " + "┈" * 36)

        print("└" + "─" * 76 + "┘\n")

#ของน้ำหวาน
class Receipt:
    """คลาสคำนวณเงินและออกใบเสร็จ (คิดตามจริงไม่มีขั้นต่ำ, ใช้แต้มใหม่ลดราคาได้ทันที)"""

    def __init__(self,
        order_id: str,
        customer,
        items: list,
        days_rented: int,
        days_late: int = 0,
        use_points_promo: bool = True,):
        self.order_id = order_id
        self.customer = customer
        self.items = items
        self.days_rented = days_rented
        self.days_late = max(0, days_late)
        self.use_points_promo = use_points_promo
        self.date_issued = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    def _calculate_rental_fee_by_days(self, days: int) -> float:
        """อัตราค่ายืม: 3 วัน 20 บาท, เศษวันละ 7 บาท (ไม่มีขั้นต่ำ)"""
        if days <= 0:
            return 0.0
        sets_of_3 = days // 3
        remaining_days = days % 3
        return (sets_of_3 * 20) + (remaining_days * 7)

    def calculate_totals(self) -> dict:
        total_books = len(self.items)

        # 1. คำนวณค่ายืมตามจริงก่อนหักส่วนลด (ไม่มีขั้นต่ำ 3 วันแล้ว)
        rental_fee_per_book = self._calculate_rental_fee_by_days(self.days_rented)
        total_rental_before_discount = total_books * rental_fee_per_book

        # 2. คำนวณแต้มที่ได้รับรอบนี้ (ยืม 1 เล่ม = 1 แต้ม, คืนตรงเวลา = +1)
        base_points = total_books
        on_time_bonus = 1 if self.days_late == 0 else 0
        earned_points = base_points + on_time_bonus

        # 3. คำนวณส่วนลด (รวมแต้มเดิม + แต้มใหม่ เพื่อแลกส่วนลด 10 แต้ม = ลด 7 บาท)
        total_discount = 0.0
        points_used = 0
        free_books_count = 0

        if self.use_points_promo:
            total_points_accumulated = self.customer.points + earned_points
            # ลดได้สูงสุดไม่เกินจำนวนเล่มที่ยืม
            free_books_count = min(total_points_accumulated // 10, total_books)
            total_discount = free_books_count * 7.0
            points_used = free_books_count * 10

        # 4. คำนวณยอดสุทธิและค่าปรับ
        total_rental_fee = max(0.0, total_rental_before_discount - total_discount)
        total_fine = total_books * self.days_late * 10
        grand_total = total_rental_fee + total_fine

        return {"total_books": total_books,
            "total_rental_before_discount": total_rental_before_discount,
            "free_books_count": free_books_count,
            "points_used": points_used,
            "total_rental_fee": total_rental_fee,
            "total_discount": total_discount,
            "total_fine": total_fine,
            "grand_total": grand_total,
            "earned_points": earned_points,}

    def print_receipt(self):
        calc = self.calculate_totals()

        # ตัดสต็อกหนังสือ
        for book in self.items:
            book.decrease_stock(1)

        # อัปเดตแต้มสมาชิก (บวกแต้มใหม่ก่อน แล้วหักแต้มที่ใช้เป็นส่วนลด)
        self.customer.add_points(calc["earned_points"])
        self.customer.points -= calc["points_used"]

        print("=" * 60)
        print(f"{'ใบเสร็จรับเงิน / Receipt':^60}")
        print("=" * 60)
        print(f"เลขที่ใบเสร็จ    : {self.order_id}")
        print(f"ชื่อลูกค้า       : คุณ{self.customer.name} (รหัส:"f" {self.customer.customer_id})")
        print(f"ระยะเวลาเช่า     : {self.days_rented} วัน")
        print("-" * 60)

        print(f"รายการหนังสือที่ยืม ({calc['total_books']} เล่ม):")
        for i, book in enumerate(self.items, 1):
            print(f"  [{i:02d}] {book.title} (ราคาปก {book.price:.0f} บาท)")

        print("-" * 60)
        print("รวมค่ายืมหนังสือ               :"f" {calc['total_rental_before_discount']:.2f} บาท")

        if calc["total_discount"] > 0:
            print(" ส่วนลดใช้แต้มแลกอ่านฟรี       :-"f"{calc['total_discount']:.2f} บาท")

        if calc["total_fine"] > 0:
            print(f" ค่าปรับคืนช้า ({self.days_late} วัน x {calc['total_books']} เล่ม"f" x 10B) : {calc['total_fine']:.2f} บาท")

        print("-" * 60)
        print(f"ยอดชำระสุทธิ (Grand Total)     : {calc['grand_total']:.2f} บาท")
        print("-" * 60)

        if calc["points_used"] > 0:
            print(f" ใช้แต้มแลกส่วนลด             : -{calc['points_used']} แต้ม")
        print(f" แต้มที่ได้รับครั้งนี้          : +{calc['earned_points']} แต้ม")
        print(f" แต้มสะสมคงเหลือปัจจุบัน      : {self.customer.points} แต้ม")
        print("=" * 60 + "\n")

import sqlite3

#ของดิว
# ==================================================
# ระบบบันทึกข้อมูล SQLite Database
# ==================================================
class DatabaseManager:
    """จัดการฐานข้อมูล SQLite สำหรับบันทึกสมาชิก หนังสือ และใบเสร็จ"""

    def __init__(self, db_name="comic_pos.db"):
        self.db_name = db_name
        self.init_db()

    def get_conn(self):
        return sqlite3.connect(self.db_name)

    def init_db(self):
        """สร้างตารางใน Database หากยังไม่มี"""
        with self.get_conn() as conn:
            cursor = conn.cursor()
            cursor.execute(
                """CREATE TABLE IF NOT EXISTS customers (customer_id TEXT PRIMARY KEY, name TEXT, phone TEXT UNIQUE,email TEXT, points INTEGER, register_date TEXT, status TEXT)""")
            cursor.execute(
                """CREATE TABLE IF NOT EXISTS books (book_isbn TEXT PRIMARY KEY, title TEXT, author TEXT,price REAL, category_id TEXT, sub_category_id TEXT,shelf_location TEXT, stock_qty INTEGER)""")
            cursor.execute(
                """CREATE TABLE IF NOT EXISTS receipts (order_id TEXT PRIMARY KEY, customer_id TEXT, days_rented INTEGER,days_late INTEGER, grand_total REAL, points_used INTEGER,earned_points INTEGER, date_issued TEXT)""")
            cursor.execute(
                """CREATE TABLE IF NOT EXISTS receipt_items (order_id TEXT, book_isbn TEXT)""")
            conn.commit()

    def save_customer(self, cust):
        """บันทึก หรือ อัปเดตข้อมูลสมาชิก"""
        with self.get_conn() as conn:
            conn.execute(
                """INSERT INTO customers VALUES (?, ?, ?, ?, ?, ?, ?) ON CONFLICT(customer_id) DO UPDATE SET name=excluded.name, phone=excluded.phone, email=excluded.email, points=excluded.points, status=excluded.status""",
                (
                    cust.customer_id,
                    cust.name,
                    cust.phone,
                    cust.email,
                    cust.points,
                    cust.register_date,
                    cust.status,
                ),)
            conn.commit()

    def save_books_from_catalog(self, catalog: list):
        """บันทึกรายการหนังสือทั้งหมดจากคลังลง Database"""
        with self.get_conn() as conn:
            for b in catalog:
                conn.execute(
                    """INSERT INTO books VALUES (?, ?, ?, ?, ?, ?, ?, ?) ON CONFLICT(book_isbn) DO UPDATE SET title=excluded.title, author=excluded.author, price=excluded.price, stock_qty=excluded.stock_qty""",
                    (
                        b.book_isbn,
                        b.title,
                        b.author,
                        b.price,
                        b.category_id,
                        b.sub_category_id,
                        b.shelf_location,
                        b.stock_qty,
                    ),)
            conn.commit()
    def save_receipt(self, receipt):
        """บันทึกใบเสร็จ อัปเดตแต้มสมาชิก และตัดสต็อกหนังสือใน DB"""
        calc = receipt.calculate_totals()
        with self.get_conn() as conn:
            # 1. บันทึกหัวใบเสร็จ
            conn.execute("""INSERT INTO receipts VALUES (?, ?, ?, ?, ?, ?, ?, ?)""",
                (receipt.order_id,
                    receipt.customer.customer_id,
                    receipt.days_rented,
                    receipt.days_late,
                    calc["grand_total"],
                    calc["points_used"],
                    calc["earned_points"],
                    receipt.date_issued,),)

            # 2. บันทึกรายการหนังสือที่ยืม + ตัดสต็อกใน DB
            for item in receipt.items:
                conn.execute("INSERT INTO receipt_items VALUES (?, ?)",(receipt.order_id, item.book_isbn),)
                conn.execute("UPDATE books SET stock_qty = ? WHERE book_isbn = ?",(item.stock_qty, item.book_isbn),)

            # 3. อัปเดตแต้มสมาชิกคงเหลือล่าสุดใน DB
            conn.execute("UPDATE customers SET points = ? WHERE customer_id = ?",(receipt.customer.points, receipt.customer.customer_id),)
            conn.commit()
        print(f" [DB] บันทึกใบเสร็จเลขที่ {receipt.order_id} ลง Database เรียบร้อย!")

def run_simulation_and_analysis():
    # --- เพิ่ม 2 บรรทัดนี้เพื่อล้างฐานข้อมูลเก่าก่อนรันใหม่เสมอ ---
    if os.path.exists("comic_pos.db"):
        os.remove("comic_pos.db")

    db = DatabaseManager("comic_pos.db")
    cust_mgr = CustomerManager()

    # 1. โหลดข้อมูลหนังสือจาก CSV จริง
    csv_url = "https://raw.githubusercontent.com/dranphphmithe-ux/Book-Rental-System-Project/refs/heads/main/books_cleaned.csv"
    catalog_mgr = BookCatalogManager(csv_url)
    db.save_books_from_catalog(catalog_mgr.catalog)

    # 2. จำลองสร้างสมาชิก 30 คน
    for i in range(1, 31):
        c = cust_mgr.register_customer(
            name=f"Customer_{i:02d}",
            phone=f"081000{i:04d}",
            email=f"user{i}@email.com",)
        db.save_customer(c)

    # 3. จำลองสร้าง 300 ออเดอร์
    successful_orders = 0
    order_counter = 1

    while successful_orders < 300:
        random_phone = f"081000{random.randint(1, 30):04d}"
        customer = cust_mgr.find_customer_by_phone(random_phone)

        available_books = [b for b in catalog_mgr.catalog if b.is_available()]

        if not available_books:
            for b in catalog_mgr.catalog:
                b.stock_qty += 10
            available_books = catalog_mgr.catalog

        selected_books = random.sample(available_books, k=min(random.randint(1, 4), len(available_books)))
        days_rented = random.choice([1, 3, 7, 10])
        days_late = (random.choice([0, 0, 0, 1, 2]) if random.random() < 0.25 else 0)

        receipt = Receipt(order_id=f"REC{order_counter:05d}",
            customer=customer,
            items=selected_books,
            days_rented=days_rented,
            days_late=days_late,)

        db.save_receipt(receipt)
        successful_orders += 1
        order_counter += 1

    print(f" จำลองข้อมูลและบันทึกลง SQLite ครบ {successful_orders} รายการเรียบร้อย!\n")

    # =================================================================
    # 4. วิเคราะห์ข้อมูลด้วย SQL Query & Pandas (ตามเกณฑ์ Deliverable 3)
    # =================================================================
    conn = db.get_conn()

    # 4.1 SQL Query (GROUP BY + aggregate + ORDER BY)
    sql_q1 = pd.read_sql_query(
        """SELECT days_rented AS 'ระยะเวลาเช่า (วัน)',
               COUNT(order_id) AS 'จำนวนออเดอร์',
               SUM(grand_total) AS 'รายได้รวม (บาท)'
        FROM receipts
        GROUP BY days_rented
        ORDER BY SUM(grand_total) DESC""",conn,)

    # 4.2 SQL Query (JOIN หลายตาราง)
    sql_q2 = pd.read_sql_query(
        """SELECT b.title AS 'ชื่อหนังสือ',
               COUNT(ri.order_id) AS 'จำนวนครั้งที่ถูกเช่า'
        FROM receipt_items ri
        JOIN books b ON ri.book_isbn = b.book_isbn
        JOIN receipts r ON ri.order_id = r.order_id
        GROUP BY b.book_isbn, b.title
        ORDER BY COUNT(ri.order_id) DESC
        LIMIT 5""",conn,)

    # 4.3 Pandas Analysis (groupby / agg / sort_values)
    df_receipts = pd.read_sql_query("SELECT * FROM receipts", conn)
    df_customers = pd.read_sql_query("SELECT * FROM customers", conn)
    df_merged = df_receipts.merge(df_customers, on="customer_id")

    # วิเคราะห์ยอดใช้จ่ายรวมของลูกค้าแต่ละคนด้วย Pandas
    pandas_analysis = df_merged.groupby("name").agg(total_spent=("grand_total", "sum"),rent_count=("order_id", "count")).sort_values("total_spent", ascending=False).head(5).reset_index()

    # =================================================================
    # 5. Export ข้อมูลเป็นไฟล์ CSV (ตามเกณฑ์ Deliverable 2)
    # =================================================================
    df_receipts.to_csv("simulated_receipts.csv", index=False, encoding="utf-8-sig")
    print(" บันทึกไฟล์จำลองข้อมูลเป็น 'simulated_receipts.csv' เรียบร้อย!\n")

    # =================================================================
    # 6. แสดงกราฟ 3 กราฟ พร้อมจัดฟอนต์ภาษาไทย
    # =================================================================
    sns.set_theme(style="whitegrid")
    plt.rcParams["font.family"] = "TH Sarabun New"

    # ปรับ layout เป็น 3 กราฟ
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# กราฟที่ 1: รายได้ตามระยะเวลาเช่าที่ลูกค้าเลือก
    sns.barplot(
        ax=axes[0],
        data=sql_q1,
        x="ระยะเวลาเช่า (วัน)",
        y="รายได้รวม (บาท)",
        hue="ระยะเวลาเช่า (วัน)",
        palette="Blues_d",
        legend=False)

    # แก้ชื่อกราฟจาก "แพ็กเกจ" เป็น "ระยะเวลาเช่า" ให้ตรงกับระบบคิดเงิน
    axes[0].set_title("1. รายได้รวมแยกตามระยะเวลาที่เลือกเช่า", fontsize=14, fontweight="bold")

    # กราฟที่ 2: Top 5 หนังสือ
    sns.barplot(ax=axes[1], data=sql_q2, x="จำนวนครั้งที่ถูกเช่า", y="ชื่อหนังสือ",hue="ชื่อหนังสือ", palette="viridis", legend=False)
    axes[1].set_title("2. Top 5 หนังสือการ์ตูนยอดฮิต", fontsize=14, fontweight="bold")

    # กราฟที่ 3: สัดส่วนการส่งคืนหนังสือ (ตรงเวลา vs คืนสาย)
    df_receipts["return_status"] = df_receipts["days_late"].apply(lambda x: "คืนสาย (Late)" if x > 0 else "ตรงเวลา (On-time)")
    status_counts = df_receipts["return_status"].value_counts()

    axes[2].pie(status_counts, labels=status_counts.index, autopct="%1.1f%%",colors=["#66b3ff", "#ff9999"], startangle=140, explode=(0, 0.1))
    axes[2].set_title("3. สัดส่วนการส่งคืนหนังสือ", fontsize=14, fontweight="bold")
# กราฟที่ 3: สัดส่วนการส่งคืนหนังสือ (ตรงเวลา vs คืนสาย)
    df_receipts["return_status"] = df_receipts["days_late"].apply(lambda x: "คืนสาย (Late)" if x > 0 else "ตรงเวลา (On-time)")
    status_counts = df_receipts["return_status"].value_counts()

    axes[2].pie(status_counts, labels=status_counts.index, autopct="%1.1f%%",colors=["#66b3ff", "#ff9999"], startangle=140, explode=(0, 0.1))
    axes[2].set_title("3. สัดส่วนการส่งคืนหนังสือ", fontsize=14, fontweight="bold")



    # 1. SQL Query 3
    sql_q3 = pd.read_sql_query( "SELECT order_id, customer_id, days_late, grand_total FROM receipts WHERE days_late > 0 ORDER BY grand_total DESC LIMIT 5", conn)
    print("[SQL Query 3] ลูกค้าที่คืนช้าและมียอดปรับสูงสุด:\n", sql_q3, "\n" + "="*60)

    # 2. Pandas Analysis (read_csv, info, describe)
    print(" สำรวจข้อมูลเบื้องต้นด้วย Pandas:")
    df_loaded = pd.read_csv("simulated_receipts.csv")
    print("\n--- ข้อมูล .info() ---")
    df_loaded.info()
    print("\n--- ข้อมูล .describe() ---")
    print(df_loaded.describe())
    print("\n" + "="*60 + "\n")

    # 3. เติม xlabel, ylabel ให้กราฟ
    axes[0].set_xlabel("ระยะเวลาเช่า (วัน)", fontsize=12)
    axes[0].set_ylabel("รายได้ (บาท)", fontsize=12)
    axes[1].set_xlabel("จำนวนครั้งที่ถูกยืม", fontsize=12)
    axes[1].set_ylabel("ชื่อหนังสือการ์ตูน", fontsize=12)


    print("กราฟรันทดสอบ")
    plt.tight_layout()
    plt.show()

    print("เนื่องจากกราฟรันทดสอบสุ่มค่าข้อมูลใหม่ทุกรอบจึงจะทำการสรุปข้อโดยการพูดจากกราฟเลยครับ")


    # 4. พิมพ์สรุปผล 3-5 ประโยค
    print("ตัวอย่างก่อนหน้าสรุปผลการวิเคราะห์ข้อมูล (Business Insights )")
    print("1. รายได้รวมเพิ่มขึ้นตามระยะเวลาแพ็กเกจเช่า โดยแพ็กเกจ 10 วัน ทำรายได้สูงสุดกว่า 12,600 บาท ซึ่งมากกว่าแพ็กเกจ 1 วันถึง 8 เท่า สะท้อนว่าลูกค้าที่เช่าระยะยาวเป็นกลุ่มรายได้หลักของร้าน")
    print("2. หนังสือยอดฮิตที่มีการยืมบ่อยที่สุดกระจุกตัวอยู่ในซีรีส์วันพีช (One Piece) ถึง 3 ใน 5 อันดับ ส่วน 'ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 18' ครองอันดับ 1 ด้วยยอดยืม 6 ครั้ง")
    print("3. สัดส่วนลูกค้าที่คืนหนังสือตรงเวลาสูงถึง 89.7% แสดงให้เห็นว่าพฤติกรรมลูกค้าโดยรวมมีวินัยดีและระบบการเช่าปัจจุบันทำงานได้อย่างมีประสิทธิภาพ")
    print("4. อย่างไรก็ตาม ลูกค้ากลุ่มที่คืนสาย (Late) แม้จะมีสัดส่วนเพียง 10.3% แต่ยังเป็นจุดที่ควรเฝ้าระวัง เพราะอาจกระทบต่อการหมุนเวียนหนังสือยอดนิยมที่มีคิวรอสูง")
    print("5. ร้านควรเน้นโปรโมทแพ็กเกจระยะยาวและเพิ่มสต็อกซีรีส์ยอดนิยมอย่างวันพีช พร้อมทั้งพิจารณาระบบแจ้งเตือนก่อนครบกำหนดคืน เพื่อลดอัตราการคืนล่าช้าให้ต่ำลงอีก")

# --- สั่งให้โปรแกรมทำงาน ---
if __name__ == "__main__":
    run_simulation_and_analysis()
# Out:
#  ระบบพร้อมใช้งาน: โหลดข้อมูลหนังสือเรียบร้อย 606 รายการ
#
# สมัครสำเร็จ [รหัส: CUST001 | ชื่อ: Customer_01 | เบอร์: 0810000001 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST002 | ชื่อ: Customer_02 | เบอร์: 0810000002 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST003 | ชื่อ: Customer_03 | เบอร์: 0810000003 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST004 | ชื่อ: Customer_04 | เบอร์: 0810000004 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST005 | ชื่อ: Customer_05 | เบอร์: 0810000005 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST006 | ชื่อ: Customer_06 | เบอร์: 0810000006 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST007 | ชื่อ: Customer_07 | เบอร์: 0810000007 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST008 | ชื่อ: Customer_08 | เบอร์: 0810000008 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST009 | ชื่อ: Customer_09 | เบอร์: 0810000009 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST010 | ชื่อ: Customer_10 | เบอร์: 0810000010 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST011 | ชื่อ: Customer_11 | เบอร์: 0810000011 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST012 | ชื่อ: Customer_12 | เบอร์: 0810000012 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST013 | ชื่อ: Customer_13 | เบอร์: 0810000013 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST014 | ชื่อ: Customer_14 | เบอร์: 0810000014 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST015 | ชื่อ: Customer_15 | เบอร์: 0810000015 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST016 | ชื่อ: Customer_16 | เบอร์: 0810000016 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST017 | ชื่อ: Customer_17 | เบอร์: 0810000017 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST018 | ชื่อ: Customer_18 | เบอร์: 0810000018 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST019 | ชื่อ: Customer_19 | เบอร์: 0810000019 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST020 | ชื่อ: Customer_20 | เบอร์: 0810000020 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST021 | ชื่อ: Customer_21 | เบอร์: 0810000021 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST022 | ชื่อ: Customer_22 | เบอร์: 0810000022 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST023 | ชื่อ: Customer_23 | เบอร์: 0810000023 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST024 | ชื่อ: Customer_24 | เบอร์: 0810000024 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST025 | ชื่อ: Customer_25 | เบอร์: 0810000025 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST026 | ชื่อ: Customer_26 | เบอร์: 0810000026 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST027 | ชื่อ: Customer_27 | เบอร์: 0810000027 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST028 | ชื่อ: Customer_28 | เบอร์: 0810000028 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST029 | ชื่อ: Customer_29 | เบอร์: 0810000029 | วันที่: 2026-09-02]
# สมัครสำเร็จ [รหัส: CUST030 | ชื่อ: Customer_30 | เบอร์: 0810000030 | วันที่: 2026-09-02]
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00001 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00002 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00003 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00004 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00005 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00006 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00007 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00008 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00009 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00010 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00011 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00012 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00013 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00014 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00015 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_07 (รหัส:CUST007แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00016 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00017 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00018 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00019 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00020 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00021 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00022 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00023 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00024 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00025 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00026 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00027 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00028 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00029 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00030 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00031 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00032 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00033 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00034 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00035 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00036 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00037 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00038 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00039 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00040 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00041 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00042 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00043 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00044 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00045 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00046 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00047 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00048 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00049 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00050 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00051 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_30 (รหัส:CUST030แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00052 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00053 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00054 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00055 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00056 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00057 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00058 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00059 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00060 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00061 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00062 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00063 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_30 (รหัส:CUST030แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00064 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00065 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00066 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00067 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00068 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00069 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_07 (รหัส:CUST007แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00070 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00071 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_30 (รหัส:CUST030แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00072 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00073 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00074 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00075 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00076 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00077 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00078 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00079 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00080 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00081 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00082 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00083 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00084 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00085 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00086 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00087 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_07 (รหัส:CUST007แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00088 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00089 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00090 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_30 (รหัส:CUST030แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00091 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00092 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00093 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00094 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00095 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00096 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00097 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00098 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00099 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00100 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00101 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00102 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00103 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00104 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00105 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00106 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00107 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00108 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00109 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00110 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00111 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00112 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00113 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00114 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00115 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00116 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00117 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00118 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00119 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00120 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00121 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00122 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00123 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00124 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00125 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00126 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00127 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00128 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00129 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00130 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00131 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00132 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00133 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00134 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00135 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_07 (รหัส:CUST007แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00136 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00137 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00138 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00139 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00140 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00141 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00142 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00143 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00144 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00145 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00146 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00147 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00148 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00149 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00150 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00151 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00152 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00153 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00154 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00155 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00156 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00157 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00158 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00159 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00160 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00161 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00162 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00163 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00164 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00165 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00166 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00167 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00168 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00169 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00170 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00171 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00172 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00173 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00174 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00175 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00176 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00177 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00178 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00179 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00180 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00181 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00182 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00183 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00184 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00185 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00186 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00187 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00188 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00189 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00190 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00191 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00192 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00193 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00194 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00195 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00196 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00197 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00198 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_14 (รหัส:CUST014แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00199 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00200 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00201 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00202 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00203 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00204 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00205 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00206 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00207 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00208 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00209 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00210 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00211 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_24 (รหัส:CUST024แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00212 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00213 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00214 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00215 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00216 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00217 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00218 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00219 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00220 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00221 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00222 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00223 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00224 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00225 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00226 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00227 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00228 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00229 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00230 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00231 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_07 (รหัส:CUST007แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00232 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00233 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_01 (รหัส:CUST001แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00234 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00235 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00236 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00237 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00238 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00239 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00240 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00241 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00242 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00243 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00244 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00245 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_21 (รหัส:CUST021แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00246 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00247 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00248 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00249 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00250 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00251 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00252 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00253 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00254 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00255 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00256 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00257 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_08 (รหัส:CUST008แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00258 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_16 (รหัส:CUST016แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00259 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00260 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00261 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_23 (รหัส:CUST023แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00262 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00263 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00264 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00265 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00266 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00267 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00268 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_19 (รหัส:CUST019แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00269 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00270 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00271 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00272 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00273 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00274 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_28 (รหัส:CUST028แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00275 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00276 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_25 (รหัส:CUST025แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00277 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00278 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_06 (รหัส:CUST006แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00279 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_04 (รหัส:CUST004แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00280 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_02 (รหัส:CUST002แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00281 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00282 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00283 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_03 (รหัส:CUST003แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00284 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_10 (รหัส:CUST010แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00285 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_13 (รหัส:CUST013แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00286 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_17 (รหัส:CUST017แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00287 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_09 (รหัส:CUST009แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00288 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_05 (รหัส:CUST005แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00289 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_18 (รหัส:CUST018แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00290 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00291 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_26 (รหัส:CUST026แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00292 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_11 (รหัส:CUST011แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00293 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_15 (รหัส:CUST015แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00294 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_29 (รหัส:CUST029แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00295 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_20 (รหัส:CUST020แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00296 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_30 (รหัส:CUST030แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00297 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_12 (รหัส:CUST012แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00298 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_22 (รหัส:CUST022แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00299 ลง Database เรียบร้อย!
# พบข้อมูล: Customer_27 (รหัส:CUST027แต้ม: 0)
#  [DB] บันทึกใบเสร็จเลขที่ REC00300 ลง Database เรียบร้อย!
#  จำลองข้อมูลและบันทึกลง SQLite ครบ 300 รายการเรียบร้อย!
#
#  บันทึกไฟล์จำลองข้อมูลเป็น 'simulated_receipts.csv' เรียบร้อย!
#
# [SQL Query 3] ลูกค้าที่คืนช้าและมียอดปรับสูงสุด:
#     order_id customer_id  days_late  grand_total
# 0  REC00055     CUST029          2        348.0
# 1  REC00101     CUST024          2        348.0
# 2  REC00160     CUST016          2        348.0
# 3  REC00138     CUST022          1        308.0
# 4  REC00142     CUST023          1        308.0
# ============================================================
#  สำรวจข้อมูลเบื้องต้นด้วย Pandas:
#
# --- ข้อมูล .info() ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       300 non-null    object
#  1   customer_id    300 non-null    object
#  2   days_rented    300 non-null    int64
#  3   days_late      300 non-null    int64
#  4   grand_total    300 non-null    float64
#  5   points_used    300 non-null    int64
#  6   earned_points  300 non-null    int64
#  7   date_issued    300 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 18.9+ KB
#
# --- ข้อมูล .describe() ---
#        days_rented   days_late  grand_total  points_used  earned_points
# count   300.000000  300.000000   300.000000        300.0     300.000000
# mean      5.516667    0.163333   101.440000          0.0       3.496667
# std       3.653430    0.480373    85.353758          0.0       1.152280
# min       1.000000    0.000000     7.000000          0.0       1.000000
# 25%       3.000000    0.000000    28.000000          0.0       2.750000
# 50%       7.000000    0.000000    67.000000          0.0       4.000000
# 75%      10.000000    0.000000   154.000000          0.0       4.000000
# max      10.000000    2.000000   348.000000          0.0       5.000000
#
# ============================================================
#
# กราฟรันทดสอบ
# เนื่องจากกราฟรันทดสอบสุ่มค่าข้อมูลใหม่ทุกรอบจึงจะทำการสรุปข้อโดยการพูดจากกราฟเลยครับ
# ตัวอย่างก่อนหน้าสรุปผลการวิเคราะห์ข้อมูล (Business Insights )
# 1. รายได้รวมเพิ่มขึ้นตามระยะเวลาแพ็กเกจเช่า โดยแพ็กเกจ 10 วัน ทำรายได้สูงสุดกว่า 12,600 บาท ซึ่งมากกว่าแพ็กเกจ 1 วันถึง 8 เท่า สะท้อนว่าลูกค้าที่เช่าระยะยาวเป็นกลุ่มรายได้หลักของร้าน
# 2. หนังสือยอดฮิตที่มีการยืมบ่อยที่สุดกระจุกตัวอยู่ในซีรีส์วันพีช (One Piece) ถึง 3 ใน 5 อันดับ ส่วน 'ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 18' ครองอันดับ 1 ด้วยยอดยืม 6 ครั้ง
# 3. สัดส่วนลูกค้าที่คืนหนังสือตรงเวลาสูงถึง 89.7% แสดงให้เห็นว่าพฤติกรรมลูกค้าโดยรวมมีวินัยดีและระบบการเช่าปัจจุบันทำงานได้อย่างมีประสิทธิภาพ
# 4. อย่างไรก็ตาม ลูกค้ากลุ่มที่คืนสาย (Late) แม้จะมีสัดส่วนเพียง 10.3% แต่ยังเป็นจุดที่ควรเฝ้าระวัง เพราะอาจกระทบต่อการหมุนเวียนหนังสือยอดนิยมที่มีคิวรอสูง
# 5. ร้านควรเน้นโปรโมทแพ็กเกจระยะยาวและเพิ่มสต็อกซีรีส์ยอดนิยมอย่างวันพีช พร้อมทั้งพิจารณาระบบแจ้งเตือนก่อนครบกำหนดคืน เพื่อลดอัตราการคืนล่าช้าให้ต่ำลงอีก

# %%
# ==========================================
# ส่วนที่ 4 — จำลอง "ลูกค้า 1 คนเดินเข้าร้านเช่าหนังสือ" แบบ step-by-step
# ==========================================
def simulate_customer_visit(order_no, db, cust_mgr, catalog_mgr):
    print(f"\n ---> ลูกค้าคิวที่ {order_no} เดินเข้าร้าน <---")

    # 1. ทักทายลูกค้า (สุ่มเบอร์โทร ถ้าเจอคนเก่าก็ทักทาย ถ้าไม่เจอก็สมัครใหม่)
    phone = f"081000{random.randint(1, 10):04d}" # สุ่มเบอร์ 10 เบอร์
    customer = cust_mgr.find_customer_by_phone(phone)
    if not customer:
        print("[1. ทักทาย] พนักงาน: ไม่พบประวัติ สมัครสมาชิกใหม่ให้นะครับ")
        customer = cust_mgr.register_customer(name=f"ลูกค้า_{phone[-4:]}", phone=phone)
    else:
        print(f"[1. ทักทาย] พนักงาน: สวัสดีครับคุณ {customer.name} แต้มสะสมมี {customer.points} แต้มครับ")

    # 2. แจ้งความจำนง (สุ่มระยะเวลายืม และสุ่มว่าคืนสายไหม)
    days_rented = random.choice([1, 2, 3, 5, 7])
    days_late = random.choice([0, 0, 0, 1, 2]) # โอกาสคืนตรงเวลาสูงกว่า
    print(f"[2. แจ้งระยะเวลา] ลูกค้า: ต้องการยืม {days_rented} วันครับ (จำลองว่าตอนมาคืน คืนช้าไป {days_late} วัน)")

    # 3. เลือกหนังสือที่พร้อมเช่า
    available_books = [b for b in catalog_mgr.catalog if b.is_available()]
    if not available_books:
        print(" ขออภัยครับ หนังสือถูกยืมหมดร้านแล้ว!")
        return

    num_books = random.randint(1, 3) # สุ่มยืม 1-3 เล่ม
    selected_books = random.sample(available_books, k=min(num_books, len(available_books)))
    book_titles = ", ".join([b.title for b in selected_books])
    print(f"[3. เลือกหนังสือ] พนักงาน: ลูกค้ารับหนังสือ {len(selected_books)} เล่ม ได้แก่ {book_titles}")

    # 4. คำนวณราคาและออกใบเสร็จ (เรียกใช้คลาส Receipt แบบใหม่)
    order_id = f"REC{order_no:05d}"
    print("[4. คำนวณเงินและออกใบเสร็จ]")
    receipt = Receipt(
        order_id=order_id,
        customer=customer,
        items=selected_books,
        days_rented=days_rented,
        days_late=days_late,
        use_points_promo=True # เปิดใช้สิทธิ์ส่วนลด
    )
    receipt.print_receipt() # พิมพ์ใบเสร็จ+หักสต็อก+อัปเดตแต้ม

    # 5. บันทึกลงฐานข้อมูล
    db.save_receipt(receipt)
    db.save_customer(customer) # อัปเดตแต้มล่าสุดลง DB
    print(f" จบคิวที่ {order_no}\n")

# ==========================================
# ส่วนที่ 5 — จำลองลูกค้าหลายคนเดินเข้าร้านต่อเนื่องกัน
# ==========================================
def run_simulation_step_by_step(num_customers=5):
    print(" เริ่มต้นเปิดร้านเช่าหนังสือการ์ตูน! ")

    # 1. เตรียมระบบหลังบ้าน
    if os.path.exists("test_simulation.db"):
        os.remove("test_simulation.db") # ล้าง DB เก่าเพื่อทดสอบ
    db = DatabaseManager("test_simulation.db")
    cust_mgr = CustomerManager()

    # 2. โหลดแคตตาล็อกหนังสือ
    csv_url = "https://raw.githubusercontent.com/dranphphmithe-ux/Book-Rental-System-Project/refs/heads/main/books_cleaned.csv"
    catalog_mgr = BookCatalogManager(csv_url)
    db.save_books_from_catalog(catalog_mgr.catalog)

    # 3. รันลูปรับลูกค้าตามจำนวนที่กำหนด
    for i in range(1, num_customers + 1):
        simulate_customer_visit(i, db, cust_mgr, catalog_mgr)

    print(" ปิดร้าน! ให้บริการลูกค้าครบแล้ว")

# --- สั่งรันจำลองสถานการณ์จริง (ลองรับลูกค้า 3 คน) ---
run_simulation_step_by_step(3)
# Out:
#  เริ่มต้นเปิดร้านเช่าหนังสือการ์ตูน!
#  ระบบพร้อมใช้งาน: โหลดข้อมูลหนังสือเรียบร้อย 606 รายการ
#
#
#  ---> ลูกค้าคิวที่ 1 เดินเข้าร้าน <---
#  ไม่พบข้อมูลสมาชิกจากเบอร์โทร: 0810000001
# [1. ทักทาย] พนักงาน: ไม่พบประวัติ สมัครสมาชิกใหม่ให้นะครับ
# สมัครสำเร็จ [รหัส: CUST001 | ชื่อ: ลูกค้า_0001 | เบอร์: 0810000001 | วันที่: 2026-09-02]
# [2. แจ้งระยะเวลา] ลูกค้า: ต้องการยืม 5 วันครับ (จำลองว่าตอนมาคืน คืนช้าไป 0 วัน)
# [3. เลือกหนังสือ] พนักงาน: ลูกค้ารับหนังสือ 3 เล่ม ได้แก่ วันพีช (One Piece) เล่ม 99, เรื่องผีรอบโลก เล่ม 20, ดาบพิฆาตอสูร (Demon Slayer) เล่ม 4
# [4. คำนวณเงินและออกใบเสร็จ]
# [ระบบแต้ม] เพิ่ม ลูกค้า_0001 +4 แต้ม (สะสมรวม: 4 แต้ม)
# ============================================================
#                   ใบเสร็จรับเงิน / Receipt
# ============================================================
# เลขที่ใบเสร็จ    : REC00001
# ชื่อลูกค้า       : คุณลูกค้า_0001 (รหัส: CUST001)
# ระยะเวลาเช่า     : 5 วัน
# ------------------------------------------------------------
# รายการหนังสือที่ยืม (3 เล่ม):
#   [01] วันพีช (One Piece) เล่ม 99 (ราคาปก 95 บาท)
#   [02] เรื่องผีรอบโลก เล่ม 20 (ราคาปก 165 บาท)
#   [03] ดาบพิฆาตอสูร (Demon Slayer) เล่ม 4 (ราคาปก 90 บาท)
# ------------------------------------------------------------
# รวมค่ายืมหนังสือ               : 102.00 บาท
# ------------------------------------------------------------
# ยอดชำระสุทธิ (Grand Total)     : 102.00 บาท
# ------------------------------------------------------------
#  แต้มที่ได้รับครั้งนี้          : +4 แต้ม
#  แต้มสะสมคงเหลือปัจจุบัน      : 4 แต้ม
# ============================================================
#
#  [DB] บันทึกใบเสร็จเลขที่ REC00001 ลง Database เรียบร้อย!
#  จบคิวที่ 1
#
#
#  ---> ลูกค้าคิวที่ 2 เดินเข้าร้าน <---
#  ไม่พบข้อมูลสมาชิกจากเบอร์โทร: 0810000005
# [1. ทักทาย] พนักงาน: ไม่พบประวัติ สมัครสมาชิกใหม่ให้นะครับ
# สมัครสำเร็จ [รหัส: CUST002 | ชื่อ: ลูกค้า_0005 | เบอร์: 0810000005 | วันที่: 2026-09-02]
# [2. แจ้งระยะเวลา] ลูกค้า: ต้องการยืม 1 วันครับ (จำลองว่าตอนมาคืน คืนช้าไป 0 วัน)
# [3. เลือกหนังสือ] พนักงาน: ลูกค้ารับหนังสือ 2 เล่ม ได้แก่ โคนัน (Detective Conan) เล่ม 49, วันพีช (One Piece) เล่ม 16
# [4. คำนวณเงินและออกใบเสร็จ]
# [ระบบแต้ม] เพิ่ม ลูกค้า_0005 +3 แต้ม (สะสมรวม: 3 แต้ม)
# ============================================================
#                   ใบเสร็จรับเงิน / Receipt
# ============================================================
# เลขที่ใบเสร็จ    : REC00002
# ชื่อลูกค้า       : คุณลูกค้า_0005 (รหัส: CUST002)
# ระยะเวลาเช่า     : 1 วัน
# ------------------------------------------------------------
# รายการหนังสือที่ยืม (2 เล่ม):
#   [01] โคนัน (Detective Conan) เล่ม 49 (ราคาปก 90 บาท)
#   [02] วันพีช (One Piece) เล่ม 16 (ราคาปก 95 บาท)
# ------------------------------------------------------------
# รวมค่ายืมหนังสือ               : 14.00 บาท
# ------------------------------------------------------------
# ยอดชำระสุทธิ (Grand Total)     : 14.00 บาท
# ------------------------------------------------------------
#  แต้มที่ได้รับครั้งนี้          : +3 แต้ม
#  แต้มสะสมคงเหลือปัจจุบัน      : 3 แต้ม
# ============================================================
#
#  [DB] บันทึกใบเสร็จเลขที่ REC00002 ลง Database เรียบร้อย!
#  จบคิวที่ 2
#
#
#  ---> ลูกค้าคิวที่ 3 เดินเข้าร้าน <---
#  ไม่พบข้อมูลสมาชิกจากเบอร์โทร: 0810000004
# [1. ทักทาย] พนักงาน: ไม่พบประวัติ สมัครสมาชิกใหม่ให้นะครับ
# สมัครสำเร็จ [รหัส: CUST003 | ชื่อ: ลูกค้า_0004 | เบอร์: 0810000004 | วันที่: 2026-09-02]
# [2. แจ้งระยะเวลา] ลูกค้า: ต้องการยืม 1 วันครับ (จำลองว่าตอนมาคืน คืนช้าไป 0 วัน)
# [3. เลือกหนังสือ] พนักงาน: ลูกค้ารับหนังสือ 1 เล่ม ได้แก่ วันพีช (One Piece) เล่ม 79
# [4. คำนวณเงินและออกใบเสร็จ]
# [ระบบแต้ม] เพิ่ม ลูกค้า_0004 +2 แต้ม (สะสมรวม: 2 แต้ม)
# ============================================================
#                   ใบเสร็จรับเงิน / Receipt
# ============================================================
# เลขที่ใบเสร็จ    : REC00003
# ชื่อลูกค้า       : คุณลูกค้า_0004 (รหัส: CUST003)
# ระยะเวลาเช่า     : 1 วัน
# ------------------------------------------------------------
# รายการหนังสือที่ยืม (1 เล่ม):
#   [01] วันพีช (One Piece) เล่ม 79 (ราคาปก 95 บาท)
# ------------------------------------------------------------
# รวมค่ายืมหนังสือ               : 7.00 บาท
# ------------------------------------------------------------
# ยอดชำระสุทธิ (Grand Total)     : 7.00 บาท
# ------------------------------------------------------------
#  แต้มที่ได้รับครั้งนี้          : +2 แต้ม
#  แต้มสะสมคงเหลือปัจจุบัน      : 2 แต้ม
# ============================================================
#
#  [DB] บันทึกใบเสร็จเลขที่ REC00003 ลง Database เรียบร้อย!
#  จบคิวที่ 3
#
#  ปิดร้าน! ให้บริการลูกค้าครบแล้ว

# %%
import os
import sqlite3
import pandas as pd

# 1. ตรวจสอบไฟล์ฐานข้อมูล
db_name = "test_simulation.db" if os.path.exists("test_simulation.db") else "comic_pos.db"

if not os.path.exists(db_name):
    print(f" ไม่พบไฟล์ฐานข้อมูล '{db_name}' กรุณารันโค้ดจำลองข้อมูลก่อนครับ")
else:
    print(f" ดึงข้อมูลจากฐานข้อมูล: {db_name}\n")
    conn = sqlite3.connect(db_name)

    # --------------------------------------------------------
    # ตารางที่ 1: รายชื่อสมาชิกทั้งหมด (Customers)
    # --------------------------------------------------------
    print("=== 1. ข้อมูลสมาชิก (Customers) ===")
    df_customers = pd.read_sql_query("SELECT * FROM customers", conn)
    display(df_customers)
    print("\n" + "=" * 70 + "\n")

    # --------------------------------------------------------
    # ตารางที่ 2: สรุปหัวใบเสร็จการเช่า (Receipts)
    # --------------------------------------------------------
    print("=== 2. ข้อมูลสรุปใบเสร็จ (Receipts) ===")
    df_receipts = pd.read_sql_query("SELECT * FROM receipts", conn)
    display(df_receipts)
    print("\n" + "=" * 70 + "\n")

    # --------------------------------------------------------
    # ตารางที่ 3: รายงานการเช่ารายเล่ม (JOIN Receipts + Customers + Books)
    # --------------------------------------------------------
    print("=== 3. รายละเอียดการเช่าหนังสือ (JOIN 4 ตาราง) ===")
    sql_join = """
        SELECT
            r.order_id AS 'เลขที่ใบเสร็จ',
            c.name AS 'ชื่อลูกค้า',
            b.title AS 'หนังสือที่ยืม',
            b.price AS 'ราคาปก',
            r.days_rented AS 'ยืม (วัน)',
            r.days_late AS 'สาย (วัน)',
            r.grand_total AS 'ยอดสุทธิ (บาท)',
            r.date_issued AS 'วันที่ทำรายการ'
        FROM receipts r
        JOIN customers c ON r.customer_id = c.customer_id
        JOIN receipt_items ri ON r.order_id = ri.order_id
        JOIN books b ON ri.book_isbn = b.book_isbn
        ORDER BY r.order_id ASC
    """
    df_details = pd.read_sql_query(sql_join, conn)
    display(df_details)
    print("\n" + "=" * 70 + "\n")

    # --------------------------------------------------------
    # ตารางที่ 4: ตัวอย่างสต็อกหนังสือคงเหลือ (Books)
    # --------------------------------------------------------
    print("=== 4. ตัวอย่างคลังหนังสือคงเหลือ (แสดง 10 เล่มแรก) ===")
    df_books = pd.read_sql_query("SELECT book_isbn, title, price, stock_qty, shelf_location FROM books LIMIT 10", conn)
    display(df_books)

    conn.close()
# Out:
#  ดึงข้อมูลจากฐานข้อมูล: test_simulation.db
#
# === 1. ข้อมูลสมาชิก (Customers) ===
#   customer_id         name       phone email  points register_date status
# 0     CUST001  ลูกค้า_0004  0810000004             6    2026-09-02   ปกติ
# 1     CUST002  ลูกค้า_0006  0810000006             2    2026-09-02   ปกติ
# ======================================================================
#
# === 2. ข้อมูลสรุปใบเสร็จ (Receipts) ===
#    order_id customer_id  days_rented  days_late  grand_total  points_used  \
# 0  REC00001     CUST001            3          0         60.0            0
# 1  REC00002     CUST001            7          0         47.0            0
# 2  REC00003     CUST002            2          0         14.0            0
#
#    earned_points          date_issued
# 0              4  2026-09-02 05:06:17
# 1              2  2026-09-02 05:06:17
# 2              2  2026-09-02 05:06:17
# ======================================================================
#
# === 3. รายละเอียดการเช่าหนังสือ (JOIN 4 ตาราง) ===
#   เลขที่ใบเสร็จ   ชื่อลูกค้า                           หนังสือที่ยืม  ราคาปก  \
# 0      REC00001  ลูกค้า_0004  ผ่าพิภพไททัน (Attack on Titan) เล่ม 31    90.0
# 1      REC00001  ลูกค้า_0004         โคนัน (Detective Conan) เล่ม 39    90.0
# 2      REC00001  ลูกค้า_0004           ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 74   165.0
# 3      REC00002  ลูกค้า_0004             วันพีช (One Piece) เล่ม 101    95.0
# 4      REC00003  ลูกค้า_0006           ล่าขุมทรัพย์สุดขอบฟ้า เล่ม 13   165.0
#
#    ยืม (วัน)  สาย (วัน)  ยอดสุทธิ (บาท)       วันที่ทำรายการ
# 0          3          0            60.0  2026-09-02 05:06:17
# 1          3          0            60.0  2026-09-02 05:06:17
# 2          3          0            60.0  2026-09-02 05:06:17
# 3          7          0            47.0  2026-09-02 05:06:17
# 4          2          0            14.0  2026-09-02 05:06:17
# ======================================================================
#
# === 4. ตัวอย่างคลังหนังสือคงเหลือ (แสดง 10 เล่มแรก) ===
#     book_isbn                                   title  price  stock_qty  \
# 0  B460101001   ผ่าพิภพไททัน (Attack on Titan) เล่ม 1   90.0          5
# 1  B460101002   ผ่าพิภพไททัน (Attack on Titan) เล่ม 2   90.0          5
# 2  B460101003   ผ่าพิภพไททัน (Attack on Titan) เล่ม 3   90.0          5
# 3  B460101004   ผ่าพิภพไททัน (Attack on Titan) เล่ม 4   90.0          5
# 4  B460101005   ผ่าพิภพไททัน (Attack on Titan) เล่ม 5   90.0          5
# 5  B460101006   ผ่าพิภพไททัน (Attack on Titan) เล่ม 6   90.0          5
# 6  B460101007   ผ่าพิภพไททัน (Attack on Titan) เล่ม 7   90.0          5
# 7  B460101008   ผ่าพิภพไททัน (Attack on Titan) เล่ม 8   90.0          5
# 8  B460101009   ผ่าพิภพไททัน (Attack on Titan) เล่ม 9   90.0          5
# 9  B460101010  ผ่าพิภพไททัน (Attack on Titan) เล่ม 10   90.0          5
#
#   shelf_location
# 0           A-01
# 1           A-01
# 2           A-01
# 3           A-01
# 4           A-01
# 5           A-01
# 6           A-01
# 7           A-01
# 8           A-01
# 9           A-01
