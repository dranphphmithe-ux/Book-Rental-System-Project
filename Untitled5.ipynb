# %% [markdown]
# <a href="https://colab.research.google.com/github/dranphphmithe-ux/Book-Rental-System-Project/blob/%E0%B8%81%E0%B8%A3/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class LibraryOder:
  def __init__(self, name, customer_id, phone, email, points, tier, register_id):
      self.name = name
      self.customer_id = customer_id
      self.phone = phone
      self.email = email
      self.points = points
      self.tier = tier
      self.register_id = register_id
      self.status = 'รอดำเนินการ'
