# %% [markdown]
# <a href="https://colab.research.google.com/github/dranphphmithe-ux/Book-Rental-System-Project/blob/main/search%20tutu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# class2 ส่วนที่1
# ค้นหาหนังสือ
# 1.ค้นหาด้วยชื่อ 2.ค้นหาด้วยรหัส ISBN
# เสร็จละ

# %%
import csv
import io
from urllib.request import urlopen

class BookSearch:
    def __init__(self, url: str):
        self.catalog = []
        # ดึงไฟล์ CSV ตรงจาก URL บน GitHub
        response = urlopen(url)
        csv_data = response.read().decode('utf-8-sig')

        # อ่านข้อมูล
        reader = csv.DictReader(io.StringIO(csv_data))
        for row in reader:
            self.catalog.append(row)

url = 'https://raw.githubusercontent.com/dranphphmithe-ux/Book-Rental-System-Project/refs/heads/main/books_cleaned.csv'
search_system = BookSearch(url)

# %%
import csv


# 1. นิยาม Class
class BookSearch:

    def __init__(self, filepath: str):
        self.catalog = []
        self.load_data(filepath)

    def load_data(self, filepath: str):
        try:
            with open(filepath, mode="r", encoding="utf-8-sig") as f:
                reader = csv.DictReader(f)
                self.catalog = [row for row in reader]
            print(
                "ระบบพร้อมใช้งาน: โหลดข้อมูลหนังสือเรียบร้อย"
                f" {len(self.catalog)} รายการ\n"
            )
        except Exception as e:
            print(f"เกิดข้อผิดพลาดในการโหลดไฟล์ CSV: {e}\n")

    def search_by_title(self, keyword: str):
        print(f"ผลการค้นหาชื่อหนังสือ: '{keyword}'")
        results = [
            b
            for b in self.catalog
            if keyword.lower() in b.get("title", "").lower()
        ]
        self._show_results(results)

    def search_by_isbn(self, isbn_code: str):
        print(f"ผลการค้นหารหัส/ISBN: '{isbn_code}'")
        results = [
            b
            for b in self.catalog
            if isbn_code.lower() in b.get("book_isbn", "").lower()
        ]
        self._show_results(results)

    def _show_results(self, results: list):
        if not results:
            print("ไม่พบข้อมูลหนังสือที่คุณต้องการค้นหา\n")
            return

        print(f"พบรายการหนังสือทั้งหมด {len(results)} รายการ")
        print("┌" + "─" * 76 + "┐")

        for i, b in enumerate(results, 1):
            isbn = b.get("book_isbn", "-")
            title = b.get("title", "-")
            author = b.get("author", "-")
            price = b.get("price", "-")
            shelf = b.get("shelf_location", "-")
            stock = b.get("stock_qty", "-")

            print(f"  [{i:02d}] {title}")
            print(
                f"       ISBN: {isbn:<14} ผู้แต่ง: {author:<22} ชั้นวาง:"
                f" {shelf}"
            )
            print(
                f"       ราคา: {price:>5} บาท             จำนวนคงเหลือ:"
                f" {stock} เล่ม"
            )

            if i < len(results):
                print("  " + "┈" * 36)

        print("└" + "─" * 76 + "┘\n")


# 2. สร้าง Object ตัวแปร
search_system = BookSearch("books_cleaned.csv")
# Out:
# ระบบพร้อมใช้งาน: โหลดข้อมูลหนังสือเรียบร้อย 606 รายการ

# %%
# 3. ทดสอบค้นหาด้วย "ชื่อ"
search_system.search_by_title("ผ่าพิภพไททัน")
# Out:
# ผลการค้นหาชื่อหนังสือ: 'ผ่าพิภพไททัน'
# พบรายการหนังสือทั้งหมด 34 รายการ
# ┌────────────────────────────────────────────────────────────────────────────┐
#   [01] ผ่าพิภพไททัน (Attack on Titan) เล่ม 1
#        ISBN: B460101001     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [02] ผ่าพิภพไททัน (Attack on Titan) เล่ม 2
#        ISBN: B460101002     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [03] ผ่าพิภพไททัน (Attack on Titan) เล่ม 3
#        ISBN: B460101003     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [04] ผ่าพิภพไททัน (Attack on Titan) เล่ม 4
#        ISBN: B460101004     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [05] ผ่าพิภพไททัน (Attack on Titan) เล่ม 5
#        ISBN: B460101005     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [06] ผ่าพิภพไททัน (Attack on Titan) เล่ม 6
#        ISBN: B460101006     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [07] ผ่าพิภพไททัน (Attack on Titan) เล่ม 7
#        ISBN: B460101007     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [08] ผ่าพิภพไททัน (Attack on Titan) เล่ม 8
#        ISBN: B460101008     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [09] ผ่าพิภพไททัน (Attack on Titan) เล่ม 9
#        ISBN: B460101009     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [10] ผ่าพิภพไททัน (Attack on Titan) เล่ม 10
#        ISBN: B460101010     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [11] ผ่าพิภพไททัน (Attack on Titan) เล่ม 11
#        ISBN: B460101011     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [12] ผ่าพิภพไททัน (Attack on Titan) เล่ม 12
#        ISBN: B460101012     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [13] ผ่าพิภพไททัน (Attack on Titan) เล่ม 13
#        ISBN: B460101013     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [14] ผ่าพิภพไททัน (Attack on Titan) เล่ม 14
#        ISBN: B460101014     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [15] ผ่าพิภพไททัน (Attack on Titan) เล่ม 15
#        ISBN: B460101015     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [16] ผ่าพิภพไททัน (Attack on Titan) เล่ม 16
#        ISBN: B460101016     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [17] ผ่าพิภพไททัน (Attack on Titan) เล่ม 17
#        ISBN: B460101017     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [18] ผ่าพิภพไททัน (Attack on Titan) เล่ม 18
#        ISBN: B460101018     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [19] ผ่าพิภพไททัน (Attack on Titan) เล่ม 19
#        ISBN: B460101019     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [20] ผ่าพิภพไททัน (Attack on Titan) เล่ม 20
#        ISBN: B460101020     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [21] ผ่าพิภพไททัน (Attack on Titan) เล่ม 21
#        ISBN: B460101021     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [22] ผ่าพิภพไททัน (Attack on Titan) เล่ม 22
#        ISBN: B460101022     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [23] ผ่าพิภพไททัน (Attack on Titan) เล่ม 23
#        ISBN: B460101023     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [24] ผ่าพิภพไททัน (Attack on Titan) เล่ม 24
#        ISBN: B460101024     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [25] ผ่าพิภพไททัน (Attack on Titan) เล่ม 25
#        ISBN: B460101025     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [26] ผ่าพิภพไททัน (Attack on Titan) เล่ม 26
#        ISBN: B460101026     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [27] ผ่าพิภพไททัน (Attack on Titan) เล่ม 27
#        ISBN: B460101027     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [28] ผ่าพิภพไททัน (Attack on Titan) เล่ม 28
#        ISBN: B460101028     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [29] ผ่าพิภพไททัน (Attack on Titan) เล่ม 29
#        ISBN: B460101029     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [30] ผ่าพิภพไททัน (Attack on Titan) เล่ม 30
#        ISBN: B460101030     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [31] ผ่าพิภพไททัน (Attack on Titan) เล่ม 31
#        ISBN: B460101031     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [32] ผ่าพิภพไททัน (Attack on Titan) เล่ม 32
#        ISBN: B460101032     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [33] ผ่าพิภพไททัน (Attack on Titan) เล่ม 33
#        ISBN: B460101033     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
#   ┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈┈
#   [34] ผ่าพิภพไททัน (Attack on Titan) เล่ม 34
#        ISBN: B460101034     ผู้แต่ง: Hajime Isayama         ชั้นวาง: A-01
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
# └────────────────────────────────────────────────────────────────────────────┘

# %%
# ทดสอบค้นหาด้วย "รหัส/ISBN"
search_system.search_by_isbn("B470101001")
# Out:
# ผลการค้นหารหัส/ISBN: 'B470101001'
# พบรายการหนังสือทั้งหมด 1 รายการ
# ┌────────────────────────────────────────────────────────────────────────────┐
#   [01] ดาบพิฆาตอสูร (Demon Slayer) เล่ม 1
#        ISBN: B470101001     ผู้แต่ง: Koyoharu Gotouge       ชั้นวาง: A-02
#        ราคา:    90 บาท             จำนวนคงเหลือ: 5 เล่ม
# └────────────────────────────────────────────────────────────────────────────┘
